# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib tk

# %%
data_all = pd.read_csv('Features.csv').dropna(axis=1)
data_all
# Out:
#          Theta     Alpha      Beta  Theta_ratio  Alpha_ratio  Beta_ratio  \
# 0     5.478965  2.526810  2.764925     0.507505     0.234057    0.258438
# 1     2.884534  1.913928  2.768027     0.390887     0.252898    0.356215
# 2     7.166805  4.005514  7.978071     0.382585     0.212711    0.404704
# 3     2.694183  2.027418  3.852692     0.318860     0.240955    0.440185
# 4     6.281124  4.022892  8.421597     0.332227     0.218676    0.449097
# ...        ...       ...       ...          ...          ...         ...
# 2695  4.819919  2.735769  3.480329     0.445228     0.241847    0.312926
# 2696  3.433117  1.952647  7.195257     0.273939     0.158074    0.567987
# 2697  5.010104  2.711312  6.274102     0.362032     0.195539    0.442428
# 2698  1.430647  1.241856  8.130359     0.137981     0.108538    0.753481
# 2699  6.494568  3.616937  9.193651     0.345569     0.187169    0.467262
#
#       TotalAbsPow  Theta_watch-relax  Alpha_watch-relax  Beta_watch-relax  \
# ...

# %% [markdown]
# # Fill all values in each column that are between 3 standard deviations with NaNs

# %%
df = data_all

# %%
df = df[~(np.abs(df[df.columns] - df[df.columns].mean()) > (3 * df[df.columns].std()))]
df
# Out:
#          Theta     Alpha      Beta  Theta_ratio  Alpha_ratio  Beta_ratio  \
# 0     5.478965  2.526810  2.764925     0.507505     0.234057    0.258438
# 1     2.884534  1.913928  2.768027     0.390887     0.252898    0.356215
# 2     7.166805  4.005514  7.978071     0.382585     0.212711    0.404704
# 3     2.694183  2.027418  3.852692     0.318860     0.240955    0.440185
# 4     6.281124  4.022892  8.421597     0.332227     0.218676    0.449097
# ...        ...       ...       ...          ...          ...         ...
# 2695  4.819919  2.735769  3.480329     0.445228     0.241847    0.312926
# 2696  3.433117  1.952647  7.195257     0.273939     0.158074    0.567987
# 2697  5.010104  2.711312  6.274102     0.362032     0.195539    0.442428
# 2698  1.430647  1.241856  8.130359     0.137981     0.108538         NaN
# 2699  6.494568  3.616937  9.193651     0.345569     0.187169    0.467262
#
#       TotalAbsPow  Theta_watch-relax  Alpha_watch-relax  Beta_watch-relax  \
# ...
